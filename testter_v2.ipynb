# %% [markdown]
# <a href="https://colab.research.google.com/github/643020514-7/643020514-7/blob/main/testter_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/Shareddrives')

# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/Shareddrives

# %%
import pandas as pd
import os
os.chdir('/content/drive/Shareddrives/Project_DataViz23data')

# %%
file_name = '/content/drive/Shareddrives/Project_DataViz23data/ectreport66.xlsx' # ชื่อไฟล์ xlsx
dfs = pd.ExcelFile(file_name) # คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names # คำสั่งเช็คว่าในไฟล์ xlsx มี seet ย่อย ในไฟล์ชื่อว่าอะไรบ้าง
# Out:
# ['Schema',
#  'result_constituencies_PartyList',
#  'result_constituencies_Candidate',
#  'result_constituencies_status',
#  'info_province',
#  'info_party_overview',
#  'info_constituency',
#  'Candidate_Constituency',
#  'Candidate_PartyList',
#  'Candidate_PM']

# %%
# select sheet page by sheet name
Schema = dfs.parse('Schema')
result_constituencies_PartyList = dfs.parse('result_constituencies_PartyList')
result_constituencies_Candidate = dfs.parse('result_constituencies_Candidate')
result_constituencies_status = dfs.parse('result_constituencies_status')
info_province = dfs.parse('info_province')
info_party_overview = dfs.parse('info_party_overview')
info_constituency = dfs.parse('info_constituency')
Candidate_constituency = dfs.parse('Candidate_Constituency')
Candidate_partyList = dfs.parse('Candidate_PartyList')
Candidate_pm = dfs.parse('Candidate_PM')
# Out:
# Exception ignored in: <function ExcelFile.__del__ at 0x7f4f93591090>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py", line 1779, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py", line 1767, in close
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py", line 574, in close
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/common.py", line 125, in close
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # Check NaN

# %%
print(result_constituencies_PartyList.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_PartyList.head()
# Out:
# cons_id                    False
# party_id                   False
# party_list_vote            False
# party_list_vote_percent    False
# dtype: bool
#   cons_id  party_id  party_list_vote  party_list_vote_percent
# 0   ACR_1       701             4550                  4.30977
# 1   ACR_1       702              185                  0.17523
# 2   ACR_1       703               67                  0.06346
# 3   ACR_1       705            33576                 31.80328
# 4   ACR_1       706              132                  0.12503

# %%
print(result_constituencies_Candidate.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_Candidate.head()
# Out:
# cons_id                False
# mp_app_id              False
# mp_app_rank            False
# mp_app_vote            False
# mp_app_vote_percent    False
# party_id               False
# dtype: bool
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
print(result_constituencies_status.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_status.head()
# Out:
# prov_id                  False
# cons_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# Unnamed: 7                True
# Unnamed: 8                True
# Unnamed: 9                True
# Unnamed: 10               True
# Unnamed: 11               True
# Unnamed: 12               True
# Unnamed: 13               True
# Unnamed: 14               True
# Unnamed: 15               True
# Unnamed: 16               True
# dtype: bool
#   prov_id cons_id  turn_out  percent_turn_out  counted_vote_stations  \
# 0     ACR   ACR_1    105574          72.60136                    310
# 1     ACR   ACR_2    111813          71.70350                    331
# 2     ATG   ATG_1     89756          80.19872                    239
# 3     ATG   ATG_2     91466          81.13075                    253
# ...

# %%
print(info_province.isnull().any()) # เช็คค่าว่าง Null
info_province.head()
# Out:
# province_id              False
# prov_id                  False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations      False
# dtype: bool
#    province_id prov_id         province                       eng abbre_thai  \
# 0           37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1           15     ATG          อ่างทอง                 ANG THONG         อท
# 2           14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
# 3           10     BKK    กรุงเทพมหานคร                   BANGKOK        กทม
# 4           38     BKN           บึงกาฬ                 BUENG KAN         บก
#
#    total_registered_vote  total_vote_stations
# 0                 301354                  641
# 1                 224656                  492
# 2                 664431                 1060
# 3                4479155                 6360
# ...

# %%
print(Candidate_constituency.isnull().any()) # เช็คค่าว่าง Null
Candidate_constituency.head()
# Out:
# mp_app_id          False
# mp_app_name        False
# mp_app_no          False
# mp_app_party_id    False
# image_url          False
# dtype: bool
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3  ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4  ACR_1_13        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
print(Candidate_partyList.isnull().any()) # เช็คค่าว่าง Null
Candidate_partyList.head()
# Out:
# party_no     False
# list_no      False
# name         False
# image_url    False
# dtype: bool
#    party_no  list_no                    name  \
# 0         1        1   นายกฤดิทัช แสงธนโยธิน
# 1         1        2     นายสุปรีย์ แสงสว่าง
# 2         1        3     นายธนภัท อุทุมพันธ์
# 3         1        4          นายทิวา ขำศิริ
# 4         1        5  นายปิยพัชร์ อ่ำสำอางค์
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/candidates/นา...
# 1  https://cdn.ectreport.com/images/candidates/นา...
# 2  https://cdn.ectreport.com/images/candidates/นา...
# 3  https://cdn.ectreport.com/images/candidates/นา...
# 4  https://cdn.ectreport.com/images/candidates/นา...

# %%
print(Candidate_pm.isnull().any()) # เช็คค่าว่าง Null
Candidate_pm.head()
# Out:
# party_no     False
# name         False
# image_url    False
# dtype: bool
#    party_no                       name  \
# 0         2          นายสุรทิน พิจารณ์
# 1         4   นายบัญชา เดชเจริญศิริกุล
# 2         5  นายเชาวฤทธิ์ ขจรพงศ์กีรติ
# 3         7        นายอนุทิน ชาญวีรกูล
# 4         9    นายชัยยพล พสุรัตน์บรรจง
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/pm_candidates...
# 1  https://cdn.ectreport.com/images/pm_candidates...
# 2  https://cdn.ectreport.com/images/pm_candidates...
# 3  https://cdn.ectreport.com/images/pm_candidates...
# 4  https://cdn.ectreport.com/images/pm_candidates...

# %%
print(info_party_overview.isnull().any()) # เช็คค่าว่าง Null
info_party_overview.head()
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
info_party_overview[info_party_overview['party_no'].isnull()] #แสดง row ที่มี party_no ว่าง
# party_no คือ เลขพรรคการเมืองในบัตรเลือกตั้ง ส.ส. บัญชีรายชื่อ
# เติมเลข 99 เพราะไม่มีในรายชื่อสมาชิกสภาผู้แทนราษฎรแบบบัญชีรายชื่อ
# ประชาสามัคคี	- 99
# พลังบูรพา - 99
# รักษ์ธรรม - 99
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# #ref for Replace NaN to 99
# https://www.pptvhd36.com/news/%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%80%E0%B8%A1%E0%B8%B7%E0%B8%AD%E0%B8%87/193829

# %% [markdown]
# #Replace Nan
# ## จากการcheck จะได้ตารางที่มีค่า Nan คือ info_party_overview และ info_constituency

# %% [markdown]
# - info_party_overview

# %%
info_party_overview[info_party_overview['party_no'].isnull()] #แสดง row ที่มี party_no ว่าง
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
# แทนค่าว่างด้วยหมายเลข 99
info_party_overview['party_no'] = info_party_overview['party_no'].fillna(99)

# %%
print(info_party_overview.isnull().any()) # เช็คค่าว่าง Null อีกรอบ
info_party_overview.head()
# Out:
# id          False
# party_no    False
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %% [markdown]
# - info_constituency

# %%
print(info_constituency.isnull().any()) # เช็คค่าว่าง Null
info_constituency.head()
# Out:
# cons_id                False
# cons_no                False
# prov_id                False
# registered_vote        False
# total_vote_stations    False
# zone                    True
# dtype: bool
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %%
import numpy as np
# แทนค่าว่าง
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'RNG', 'อำเภอเมืองระนอง', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SBR', 'อำเภอเมืองสิงห์บุรี', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SKM', 'อำเภอเมืองสมุทรสงคราม', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'TRT', 'อำเภอเมืองตราด', info_constituency['zone'])

# %% [markdown]
# #Check NaN again

# %%
print(info_party_overview.isnull().any()) # เช็คค่าว่าง Null อีกรอบ
info_party_overview.head()
# Out:
# id          False
# party_no    False
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
print(info_constituency.isnull().any()) # เช็คค่าว่าง Null
info_constituency.head()
# Out:
# cons_id                False
# cons_no                False
# prov_id                False
# registered_vote        False
# total_vote_stations    False
# zone                   False
# dtype: bool
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %% [markdown]
# # Merge Table

# %%
table_merge = result_constituencies_Candidate.merge(Candidate_constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(table_merge.shape)
table_merge.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
table_merge1 = table_merge.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(table_merge1.shape)
table_merge1.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  706      14.0
# ...

# %%
table_merge2 = table_merge1.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (4781, 32)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  Unnamed: 7  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...         NaN
# ...

# %%
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 38)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  Unnamed: 13  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          NaN
# ...

# %% [markdown]
# ##Add Regian

# %%
#สร้างตารางตัวแปร data_city โดยเขียนข้อมูลในตารางทีล่ะบรรทัด
data_city = [  {'province':'กาฬสินธุ์',' region':'ตะวันออกเฉียงเหนือ'},
                    {'province':'ขอนแก่น',' region':'ตะวันออกเฉียงเหนือ'},
                    {'province':'ชัยภูมิ',' region':'ตะวันออกเฉียงเหนือ'},
                    {'province':'นครพนม',' region':'ตะวันออกเฉียงเหนือ'},
                    {'province':'นครราชสีมา',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'บึงกาฬ',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'บุรีรัมย์',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'มหาสารคาม',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'มุกดาหาร',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'ยโสธร',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'ร้อยเอ็ด',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'เลย',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'ศรีสะเกษ',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'สกลนคร',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'สุรินทร์',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'หนองคาย',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'หนองบัวลำภู',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'อุบลราชธานี',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'อุดรธานี',' region':'ตะวันออกเฉียงเหนือ'},
                  {'province':'อำนาจเจริญ',' region':'ตะวันออกเฉียงเหนือ'},

    ###แถว 2
                    {'province':'เชียงใหม่',' region':'เหนือ'},
                  {'province':'เชียงราย',' region':'เหนือ'},
                  {'province':'น่าน',' region':'เหนือ'},
                  {'province':'พะเยา',' region':'เหนือ'},
                  {'province':'แพร่',' region':'เหนือ'},
                  {'province':'แม่ฮ่องสอน',' region':'เหนือ'},
                  {'province':'ลำปาง',' region':'เหนือ'},
                  {'province':'ลำพูน',' region':'เหนือ'},
                  {'province':'อุตรดิตถ์',' region':'เหนือ'},


    ###แถว 3
                    {'province':'อุทัยธานี',' region':'กลาง'},
                  {'province':'ชัยนาท',' region':'กลาง'},
                  {'province':'สิงห์บุรี',' region':'กลาง'},
                  {'province':'อ่างทอง',' region':'กลาง'},
                  {'province':'พระนครศรีอยุธยา',' region':'กลาง'},
                  {'province':'ลพบุรี',' region':'กลาง'},
                  {'province':'สระบุรี',' region':'กลาง'},
                  {'province':'นครนายก',' region':'กลาง'},
                 {'province':'สุโขทัย',' region':'กลาง'},
                  {'province':'กรุงเทพมหานคร',' region':'กลาง'},
                  {'province':'นนทบุรี',' region':'กลาง'},
                  {'province':'ปทุมธานี',' region':'กลาง'},
                  {'province':'สมุทรปราการ',' region':'กลาง'},
                  {'province':'สมุทรสาคร',' region':'กลาง'},
                  {'province':'สมุทรสงคราม',' region':'กลาง'},
                  {'province':'นครปฐม',' region':'กลาง'},
                  {'province':'นครสวรรค์',' region':'กลาง'},
                  {'province':'สุพรรณบุรี',' region':'กลาง'},
                  {'province':'เพชรบูรณ์',' region':'กลาง'},
                    {'province':'พิจิตร',' region':'กลาง'},
                  {'province':'พิษณุโลก',' region':'กลาง'},
                  {'province':'กำแพงเพชร',' region':'กลาง'},

    ###แถว
                    {'province':'ชุมพร',' region':'ใต้'},
                  {'province':'นครศรีธรรมราช',' region':'ใต้'},
                  {'province':'นราธิวาส',' region':'ใต้'},
                  {'province':'ปัตตานี',' region':'ใต้'},
                  {'province':'พัทลุง',' region':'ใต้'},
                  {'province':'สงขลา',' region':'ใต้'},
                  {'province':'สุราษฎร์ธานี',' region':'ใต้'},
                  {'province':'ยะลา',' region':'ใต้'},
                  {'province':'กระบี่',' region':'ใต้'},
                  {'province':'พังงา',' region':'ใต้'},
                  {'province':'ภูเก็ต',' region':'ใต้'},
                  {'province':'ระนอง',' region':'ใต้'},
                  {'province':'สตูล',' region':'ใต้'},
                  {'province':'ตรัง',' region':'ใต้'},

     ### แถว5
                    {'province':'จันทบุรี',' region':'ตะวันออก'},
                    {'province':'ฉะเชิงเทรา',' region':'ตะวันออก'},
                    {'province':'ชลบุรี',' region':'ตะวันออก'},
                    {'province':'ตราด',' region':'ตะวันออก'},
                    {'province':'ปราจีนบุรี',' region':'ตะวันออก'},
                    {'province':'ระยอง',' region':'ตะวันออก'},
                    {'province':'สระแก้ว',' region':'ตะวันออก'},

   ### แถว6
                   {'province':'กาญจนบุรี',' region':'ตะวันตก'},
                   {'province':'ตาก',' region':'ตะวันตก'},
                    {'province':'ประจวบคีรีขันธ์',' region':'ตะวันตก'},
                   {'province':'เพชรบุรี',' region':'ตะวันตก'},
                   {'province':'ราชบุรี',' region':'ตะวันตก'}]

# %%
Region = pd.DataFrame(data_city)
Region
# Out:
#            province              region
# 0         กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# 1           ขอนแก่น  ตะวันออกเฉียงเหนือ
# 2           ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 3            นครพนม  ตะวันออกเฉียงเหนือ
# 4        นครราชสีมา  ตะวันออกเฉียงเหนือ
# ..              ...                 ...
# 72        กาญจนบุรี             ตะวันตก
# 73              ตาก             ตะวันตก
# 74  ประจวบคีรีขันธ์             ตะวันตก
# 75         เพชรบุรี             ตะวันตก
# 76          ราชบุรี             ตะวันตก
#
# [77 rows x 2 columns]

# %%
table_merge4 = table_merge3.merge(Region, how ='left', left_on='province',right_on='province')
print(table_merge4.shape)
table_merge4.head()
# Out:
# (4781, 39)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  Unnamed: 14  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          NaN
# ...

# %%
## เขตการเลือกตั้ง
cons_id = table_merge4['cons_id'].tolist()
cons_no = []
for i in range(len(cons_id)):
  re = cons_id[i].split('_')[-1]
  cons_no.append(re)
table_merge4['cons_no'] = cons_no

# %%
print(table_merge4.isnull().any()) # เช็คค่าว่าง Null
table_merge4.isnull()
# Out:
# cons_id                  False
# mp_app_id                False
# mp_app_rank              False
# mp_app_vote              False
# mp_app_vote_percent      False
# party_id                 False
# mp_app_name              False
# mp_app_no                False
# mp_app_party_id          False
# image_url                False
# id                       False
# party_no                 False
# name                     False
# abbr                     False
# color                    False
# logo_url                 False
# prov_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# Unnamed: 7                True
# Unnamed: 8                True
# Unnamed: 9                True
# Unnamed: 10               True
# Unnamed: 11               True
# Unnamed: 12               True
# Unnamed: 13               True
# Unnamed: 14               True
# ...

# %% [markdown]
# #sthtggsggsgd

# %%
print(table_merge4.isnull().any())
# Out:
# cons_id                  False
# mp_app_id                False
# mp_app_rank              False
# mp_app_vote              False
# mp_app_vote_percent      False
# party_id                 False
# mp_app_name              False
# mp_app_no                False
# mp_app_party_id          False
# image_url                False
# id                       False
# party_no                 False
# name                     False
# abbr                     False
# color                    False
# logo_url                 False
# prov_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# Unnamed: 7                True
# Unnamed: 8                True
# Unnamed: 9                True
# Unnamed: 10               True
# Unnamed: 11               True
# Unnamed: 12               True
# Unnamed: 13               True
# Unnamed: 14               True
# ...

# %%
table_merge4.to_csv('table_merge_new.csv', index=False)

# %%
result_constituencies_PartyList.to_csv('PartyList_vote.csv', index=False)

# %%
result_constituencies_status[['cons_id','pause_report']]
# Out:
#     cons_id  pause_report
# 0     ACR_1         False
# 1     ACR_2         False
# 2     ATG_1         False
# 3     ATG_2         False
# 4     AYA_1         False
# ..      ...           ...
# 395   YLA_2         False
# 396   YLA_3         False
# 397   YST_1         False
# 398   YST_2         False
# 399   YST_3         False
#
# [400 rows x 2 columns]

# %%
info_constituency[['cons_id','zone']]
# Out:
#      cons_id                                         zone
# 0      ACR_1                         อำเภอเมืองอำนาจเจริญ
# 1      ACR_1                                อำเภอหัวตะพาน
# 2      ACR_2                              อำเภอเสนางคนิคม
# 3      ACR_2                                 อำเภอชานุมาน
# 4      ACR_2                             อำเภอปทุมราชวงศา
# ...      ...                                          ...
# 1131   YST_2  อำเภอป่าติ้ว (ยกเว้นตำบลศรีฐาน, ตำบลกระจาย)
# 1132   YST_2                               อำเภอมหาชนะชัย
# 1133   YST_3                                อำเภอเลิงนกทา
# 1134   YST_3   อำเภอไทยเจริญ (ยกเว้นตำบลน้ำคำ, ตำบลคำไผ่)
# 1135   YST_3                                  อำเภอกุดชุม
#
# [1136 rows x 2 columns]

# %%
result_constituencies_Candidate[['cons_id','party_id']]
# Out:
#      cons_id  party_id
# 0      ACR_1       706
# 1      ACR_1       709
# 2      ACR_1       712
# 3      ACR_1       742
# 4      ACR_1       761
# ...      ...       ...
# 4776   YST_3       709
# 4777   YST_3       763
# 4778   YST_3       712
# 4779   YST_3       769
# 4780   YST_3       726
#
# [4781 rows x 2 columns]

# %%
info_party_overview[['id','name']]
# Out:
#      id           name
# 0   701   ประชาธิปัตย์
# 1   702     ประชากรไทย
# 2   703   ความหวังใหม่
# 3   705       เพื่อไทย
# 4   706  ชาติพัฒนากล้า
# ..  ...            ...
# 65  780    ไทยก้าวหน้า
# 66  781           พลัง
# 67  783  ชาติรุ่งเรือง
# 68  784       รวมใจไทย
# 69  786        เปลี่ยน
#
# [70 rows x 2 columns]

# %% [markdown]
# #คะแนนรวมปาตี้ลิส
#
# ref:https://workpointtoday.com/election-calculation-formula/

# %% [markdown]
# - คะแนนดิบ

# %%
import pandas as pd

# Merge result_constituencies_Candidate with info_party_overview on 'party_id' and 'id'
merged_df = result_constituencies_Candidate[['party_id', 'mp_app_rank']].merge(
    info_party_overview[['id', 'name']], left_on='party_id', right_on='id', how='left'
)

# Select the desired columns
final_merged_df = merged_df[['party_id', 'mp_app_rank', 'name']]

# Filter rows where 'mp_app_rank' is equal to 1
rank_counts = final_merged_df[final_merged_df['mp_app_rank'] == 1]

# Group by 'name' and count the occurrences of '1'
rank_counts = rank_counts.groupby('name')['mp_app_rank'].count().reset_index()

# Rename the count column
rank_counts = rank_counts.rename(columns={'mp_app_rank': 'raw_score'})

# Print the final DataFrame with counts of '1'

rank_counts
# Out:
#                name  raw_score
# 0           ก้าวไกล        113
# 1     ชาติพัฒนากล้า          1
# 2      ชาติไทยพัฒนา          9
# 3         ประชาชาติ          7
# 4      ประชาธิปัตย์         22
# 5      พลังประชารัฐ         39
# 6         ภูมิใจไทย         67
# 7   รวมไทยสร้างชาติ         23
# 8          เพื่อไทย        112
# 9    เพื่อไทรวมพลัง          2
# 10      ไทยสร้างไทย          5

# %% [markdown]
# - คะแนนปารตี้ลิสยังไม่รวม

# %%
import pandas as pd

# Merge result_constituencies_PartyList with info_party_overview on 'party_id'
merged_df = result_constituencies_PartyList[['party_id', 'party_list_vote']].merge(
    info_party_overview[['id', 'name']], left_on='party_id', right_on='id', how='inner'
)

# Select only the desired columns
final_merged_df = merged_df[['party_id', 'party_list_vote', 'name']]

# Group by 'name' and calculate the sum of 'party_list_vote' for each group
party_vote_totals = final_merged_df.groupby('name')['party_list_vote'].sum().reset_index()

# Rename the 'party_list_vote' column to 'total_party_list_vote' if needed
party_vote_totals.rename(columns={'party_list_vote': 'total_party_list_vote'}, inplace=True)

party_vote_totals

# %%
df_party = party_vote_totals

# คำนวณคะแนนเฉลี่ยต่อ ส.ส.บัญชีรายชื่อ 1 คน
average_vote_per_mp = df_party['total_party_list_vote'].sum() / 100

# คำนวณจำนวน ส.ส. แบบบัญชีรายชื่อที่แต่ละพรรคได้รับ
df_party['mp_count'] = df_party['total_party_list_vote'] // average_vote_per_mp

# กรณีส.ส.บัญชีรายชื่อยังได้ไม่ครบ 100 คน
# ให้พรรคการเมืองที่มีผลลัพธ์ที่เป็นเศษมากที่สุดได้รับส.ส.บัญชีรายชื่อเพิ่ม 1 คนเรียงตามลำดับ จนครบ 100 คน

# กรณีส.ส.บัญชีรายชื่อยังได้ไม่ครบ 100 คน
# ให้พรรคการเมืองที่มีผลลัพธ์ที่เป็นเศษมากที่สุดได้รับส.ส.บัญชีรายชื่อเพิ่ม 1 คนเรียงตามลำดับ จนครบ 100 คน
remaining_seats = 100 - df_party['mp_count'].sum()
added_party_indices = []  # สร้างรายการเพื่อติดตามพรรคที่ได้รับการเพิ่มแล้ว
while remaining_seats > 0:
    # หาพรรคที่มีผลลัพธ์เศษมากที่สุดแต่ยังไม่ได้รับการเพิ่ม
    max_fractional_index = (df_party['total_party_list_vote'] % average_vote_per_mp)
    max_fractional_index = max_fractional_index.idxmax()
    while max_fractional_index in added_party_indices:
        # หาพรรคถัดไปที่มีผลลัพธ์เศษมากที่สุดแต่ยังไม่ได้รับการเพิ่ม
        df_party.at[max_fractional_index, 'total_party_list_vote'] = 0
        max_fractional_index = (df_party['total_party_list_vote'] % average_vote_per_mp)
        max_fractional_index = max_fractional_index.idxmax()
    df_party.at[max_fractional_index, 'mp_count'] += 1
    added_party_indices.append(max_fractional_index)
    remaining_seats -= 1


df_party[['name', 'mp_count']]
# Out:
#                   name  mp_count
# 0                 กรีน       0.0
# 1              ก้าวไกล      39.0
# 2   ครูไทยเพื่อประชาชน       1.0
# 3              คลองไทย       0.0
# 4         ความหวังใหม่       0.0
# ..                 ...       ...
# 62           ไทยรวมไทย       0.0
# 63        ไทยศรีวิไลย์       0.0
# 64           ไทยสมาร์ท       0.0
# 65         ไทยสร้างไทย       1.0
# 66        ไทยเป็นหนึ่ง       0.0
#
# [67 rows x 2 columns]

# %%
papa = rank_counts.merge(df_party,how='left',on='name')

# %%
papa2 =papa[['name','raw_score','mp_count']]
papa2['final_score']=papa2['raw_score']+papa2['mp_count']
papa2

# %%
papa2.to_csv('final_score_partylist.csv', index=False)

# %% [markdown]
# - หยุดนับตามอำเภอ

# %%
import pandas as pd

# Merge result_constituencies_status with info_constituency on 'cons_id'
merged_df11 = result_constituencies_status[['cons_id', 'pause_report']].merge(
    info_constituency[['cons_id', 'zone']], on='cons_id', how='left'
)

# Merge merged_df1 with result_constituencies_Candidate on 'cons_id'
merged_df22 = merged_df11.merge(
    result_constituencies_Candidate[['cons_id', 'party_id']], on='cons_id', how='left'
)

# Merge merged_df2 with info_party_overview on 'party_id'
final_merged_df = merged_df22.merge(
    info_party_overview[['id']], left_on='party_id', right_on='id', how='left'
)

# Replace 'True' with 'หยุดนับคะแนน' and 'False' with 'ไม่หยุดนับคะแนน' in the 'pause_report' column
final_merged_df['pause_report'] = final_merged_df['pause_report'].replace(True, 'หยุดนับคะแนน')
final_merged_df['pause_report'] = final_merged_df['pause_report'].replace(False, 'ไม่หยุดนับคะแนน')

# Separate the DataFrame into two based on 'pause_report' values
pause_report_true_df = final_merged_df[final_merged_df['pause_report'] == 'หยุดนับคะแนน']
pause_report_false_df = final_merged_df[final_merged_df['pause_report'] == 'ไม่หยุดนับคะแนน']

# Remove duplicates from the 'zone' column
pause_report_true_df = pause_report_true_df.drop_duplicates(subset=['zone'])
pause_report_false_df = pause_report_false_df.drop_duplicates(subset=['zone'])

pause_report_true_df.to_csv('nostop.csv', index=True)
pause_report_false_df.to_csv('stop.csv', index=False)

# %% [markdown]
# - คะแนนรวมแต่ละพรรค

# %%
import pandas as pd

# Merge result_constituencies_PartyList with info_party_overview on 'party_id'
merged_df = result_constituencies_PartyList[['party_id', 'party_list_vote']].merge(
    info_party_overview[['id', 'name']], left_on='party_id', right_on='id', how='inner'
)

# Select only the desired columns
final_merged_df = merged_df[['party_id', 'party_list_vote', 'name']]

# Group by 'name' and calculate the sum of 'party_list_vote' for each group
party_vote_totals = final_merged_df.groupby('name')['party_list_vote'].sum().reset_index()

# Rename the 'party_list_vote' column to 'total_party_list_vote' if needed
party_vote_totals.rename(columns={'party_list_vote': 'total_party_list_vote'}, inplace=True)


party_vote_totals.to_csv('partylist_vote_totals.csv', index=False)
# Out:
#                   name  total_party_list_vote
# 0                 กรีน                  21559
# 1              ก้าวไกล               14233895
# 2   ครูไทยเพื่อประชาชน                 172963
# 3              คลองไทย                   7835
# 4         ความหวังใหม่                  10687
# ..                 ...                    ...
# 62           ไทยรวมไทย                  71854
# 63        ไทยศรีวิไลย์                  23404
# 64           ไทยสมาร์ท                  10235
# 65         ไทยสร้างไทย                 338042
# 66        ไทยเป็นหนึ่ง                  13424
#
# [67 rows x 2 columns]

# %% [markdown]
# - ผู้มาใช้สิทธิ์แต่ละจังหวัด

# %%
import pandas as pd

# Merge result_constituencies_status with info_province on 'prov_id'
merged_df = result_constituencies_status[['prov_id', 'turn_out']].merge(
    info_province[['prov_id', 'province']], on='prov_id', how='left'
)

# Select the desired columns
final_merged_df = merged_df[['province', 'turn_out']]

filtered_df = final_merged_df[final_merged_df['turn_out'] < 80000]

# Remove duplicates in the 'province' column
filtered_df = filtered_df.drop_duplicates(subset=['province'])

filtered_df.to_csv('ผู้มาใช้สิทธิ์.csv', index=False)

# %%
df_true.to_csv('stop.csv', index=False)

# %% [markdown]
# #fsfsgffdgsg

# %%
table_merge4 = pd.merge(table_merge3, info_constituency, on=['cons_id','prov_id'],how= 'left')
print(table_merge4.shape)
table_merge4.head()

# %%
table_merge5 = pd.merge(table_merge4, Candidate_partyList, on=['party_no'],how= 'left')
print(table_merge5.shape)
table_merge5.head()

# %%
table_merge6 = pd.merge(table_merge5, Candidate_pm, on=['party_no'],how= 'left')
print(table_merge6.shape)
table_merge6.head()

# %%
table_merge8 = table_merge6.merge(Region, how='left', left_on=['province'], right_on=['province'])

print(table_merge8)
table_merge8.head(10)

# %%
## เขตการเลือกตั้ง
cons_id = table_merge8['cons_id'].tolist()
cons_no = []
for i in range(len(cons_id)):
  re = cons_id[i].split('_')[-1]
  cons_no.append(re)
table_merge8['cons_no'] = cons_no

# %%
print(table_merge8.isnull().any())
